# %% [markdown]
# # File overview
#
#
# **train.csv**
# building_id - Foreign key for the building metadata.
# meter - The meter id code. Read as {0: electricity, 1: chilledwater, 2: steam, 3: hotwater}.
# Not every building has all meter types.<br>
# meter_reading - The target variable. Unit: kWh or kBTU(electricity site 0), 1 kWh = 3.412 kBtu (https://www.kaggle.com/c/ashrae-energy-prediction/discussion/119261)
#
# **building_meta.csv**<br>
# site_id - Foreign key for the weather files.
# building_id - Foreign key for training.csv
# primary_use - Indicator of the primary category of activities for the building based on EnergyStar property type definitions<br>
# square_feet - Gross floor area of the building<br>
# year_built - Year building was opened<br>
# floor_count - Number of floors of the building
#
# **weather_[train/test].csv**
# Weather data from a meteorological station as close as possible to the site.
# site_id
# air_temperature - Degrees Celsius
# cloud_coverage - Portion of the sky covered in clouds, in oktas
# dew_temperature - Degrees Celsius
# precip_depth_1_hr - Millimeters
# sea_level_pressure - Millibar/hectopascals
# wind_direction - Compass direction (0-360)
# wind_speed - Meters per second
#
# **test.csv**
# The submission files use row numbers for ID codes in order to save space on the file uploads. test.csv has no feature data; it exists so you can get your predictions into the correct order.
# row_id - Row id for your submission file
# building_id - Building id code
# meter - The meter id code
# timestamp - Timestamps for the test data period
#
# Reference: https://www.kaggle.com/competitions/ashrae-energy-prediction/overview

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno

# %%
df_train = pd.read_csv('D:/GSU/Data mining/project/train.csv')
df_weather_train = pd.read_csv('D:/GSU/Data mining/project/weather_train.csv')
df_meta = pd.read_csv('D:/GSU/Data mining/project/building_metadata.csv')

# %%
df_test = pd.read_csv('D:/GSU/Data mining/project/test.csv')
df_weather_test = pd.read_csv('D:/GSU/Data mining/project/weather_test.csv')
df_subission = pd.read_csv('D:/GSU/Data mining/project/sample_submission.csv')

# %%
def memory_condenser(df):
    import numpy as np
    before = df.memory_usage().sum()
    
    for column in df.columns:
        
        # if there are 10 or less values, then it can be changed to category
        if len(df[column].unique()) <= 10:
            df[column] = df[column].astype('category')
        
        
        # if the values are numeric
        if df[column].dtype in ['int64', 'float64']:
            min_value = df[column].min()
            max_value = df[column].max()
        
        if df[column].dtype == 'int64':
            if max_value <= 127 and min_value >= -128:
                df[column] = df[column].astype('int8')
            elif max_value <= 32767 and min_value >= -32768:
                df[column] = df[column].astype('int16')
            elif max_value <= 2147483647 and min_value >= -2147483648:
                df[column] = df[column].astype('int32')
        
        
        elif df[column].dtype == 'float64':
            if max_value <= np.finfo(np.float16).max and min_value >= np.finfo(np.float16).min:
                df[column] = df[column].astype('float16')
            elif max_value <= np.finfo(np.float32).max and min_value >= np.finfo(np.float32).min:
                df[column] = df[column].astype('float32')
        
    after = df.memory_usage().sum()
    print('Decrease %:', ((before-after)/before)*100 )
    
    return df

# %%
# To reduce memory
df_train = memory_condenser(df_train)
df_weather_train = memory_condenser(df_weather_train)
df_meta = memory_condenser(df_meta)

df_test = memory_condenser(df_test)
df_weather_test = memory_condenser(df_weather_test)
# Out:
# Decrease %: 53.124957954312066
# Decrease %: 68.0546899655239
# Decrease %: 60.3056831228473
# Decrease %: 53.12497961513568
# Decrease %: 68.05511916264929

# %%
df_train.head()
# Out:
#    building_id meter            timestamp  meter_reading
# 0            0     0  2016-01-01 00:00:00            0.0
# 1            1     0  2016-01-01 00:00:00            0.0
# 2            2     0  2016-01-01 00:00:00            0.0
# 3            3     0  2016-01-01 00:00:00            0.0
# 4            4     0  2016-01-01 00:00:00            0.0

# %%
df_train.loc[0]
# Out:
# building_id                        0
# meter                              0
# timestamp        2016-01-01 00:00:00
# meter_reading                    0.0
# Name: 0, dtype: object

# %%
df_meta[0:100]
# Out:
#     site_id  building_id          primary_use  square_feet  year_built  \
# 0         0            0            Education         7432      2008.0
# 1         0            1            Education         2720      2004.0
# 2         0            2            Education         5376      1991.0
# 3         0            3            Education        23685      2002.0
# 4         0            4            Education       116607      1975.0
# ..      ...          ...                  ...          ...         ...
# 95        0           95  Lodging/residential       200933      2006.0
# 96        0           96  Lodging/residential       200933      2006.0
# 97        0           97  Lodging/residential       187647      2007.0
# 98        0           98  Lodging/residential       200933      2007.0
# 99        0           99               Office         2260      2016.0
#
#     floor_count
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...

# %%
missingno.matrix(df_meta)
# Out:
# <AxesSubplot:>

# %%
df_weather_train[0:20]
# Out:
#     site_id            timestamp  air_temperature  cloud_coverage  \
# 0         0  2016-01-01 00:00:00        25.000000             6.0
# 1         0  2016-01-01 01:00:00        24.406250             NaN
# 2         0  2016-01-01 02:00:00        22.796875             2.0
# 3         0  2016-01-01 03:00:00        21.093750             2.0
# 4         0  2016-01-01 04:00:00        20.000000             2.0
# 5         0  2016-01-01 05:00:00        19.406250             NaN
# 6         0  2016-01-01 06:00:00        21.093750             6.0
# 7         0  2016-01-01 07:00:00        21.093750             NaN
# 8         0  2016-01-01 08:00:00        20.593750             NaN
# 9         0  2016-01-01 09:00:00        21.093750             NaN
# 10        0  2016-01-01 10:00:00        21.093750             NaN
# 11        0  2016-01-01 11:00:00        20.593750             NaN
# 12        0  2016-01-01 12:00:00        18.906250             6.0
# ...

# %%
missingno.matrix(df_weather_train)
# Out:
# <AxesSubplot:>

# %%
df_inner = pd.merge(df_train, df_meta, on='building_id', how='left')

# %%
df_inner['building_id'].values
# Out:
# array([   0,    1,    2, ..., 1446, 1447, 1448], dtype=int16)

# %%
df_train_total = pd.merge(df_inner, df_weather_train, on = ['timestamp','site_id'], how='left')

# %%
# To change column sequence 
df = df_train_total[['timestamp', 'building_id', 'site_id',
                     'square_feet', 'year_built', 'floor_count',
                     'air_temperature', 'cloud_coverage', 'dew_temperature',
                     'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction',
                     'wind_speed', 'meter', 'meter_reading']]
# To change timestamp to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['day'] = df['timestamp'].dt.date
df['month'] = df['timestamp'].dt.month

df.info()
# Out:
# C:\Users\JINSUH~1\AppData\Local\Temp/ipykernel_24940/3170900873.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp'] = pd.to_datetime(df['timestamp'])
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20216100 entries, 0 to 20216099
# Data columns (total 17 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   timestamp           datetime64[ns]
#  1   building_id         int16
#  2   site_id             int8
#  3   square_feet         int32
#  4   year_built          float16
#  5   floor_count         float16
#  6   air_temperature     float16
#  7   cloud_coverage      float16
#  8   dew_temperature     float16
#  9   precip_depth_1_hr   float16
#  10  sea_level_pressure  float16
# ...

# %%
# To convert kBTU (meter 0 of site 0) into kWh
# check detial information here(https://www.kaggle.com/c/ashrae-energy-prediction/discussion/119261)
con1 = df['site_id']==0
con2 = df['meter'] == 0
df.loc[con1&con2,'meter_reading'] = df.loc[con1&con2,'meter_reading']/3.412

# %%
df.head()
# Out:
#    timestamp  building_id  site_id  square_feet  year_built  floor_count  \
# 0 2016-01-01            0        0         7432      2008.0          NaN
# 1 2016-01-01            1        0         2720      2004.0          NaN
# 2 2016-01-01            2        0         5376      1991.0          NaN
# 3 2016-01-01            3        0        23685      2002.0          NaN
# 4 2016-01-01            4        0       116607      1975.0          NaN
#
#    air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 0             25.0             6.0             20.0                NaN
# 1             25.0             6.0             20.0                NaN
# 2             25.0             6.0             20.0                NaN
# 3             25.0             6.0             20.0                NaN
# 4             25.0             6.0             20.0                NaN
#
#    sea_level_pressure  wind_direction  wind_speed meter  meter_reading  \
# ...

# %%
# Data quality report for continuous features
num_col_list = ['building_id','site_id','square_feet','year_built',
               'floor_count','air_temperature','cloud_coverage','dew_temperature',
               'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction', 'wind_speed',
               'meter_reading']
df_check = df[num_col_list]

dic_new_numerric = {}
for (name, series) in df_check.iteritems():
    dic_new_numerric[name] = [(series.size), # Desc / count 
                              (series.isnull().sum()/series.size)*100, series.unique().size, # %ofMissing / Card. 
                              df[name].min(), df[name].quantile(0.25), # Min / Q1
                              df[name].median(), df[name].quantile(0.75), # Median / Q3
                              df[name].max(), df[name].mean(), df[name].std()," "] # Max / Mean / Std.Dev / Notes

df_qual_report = pd.DataFrame(dic_new_numerric, index=['Count','% of Missing','Card.','Min.', 'Q1', 'Median', 'Q3', 'Max', 'Mean', 'Std.Dev.', "Notes"])
df_qual_report = df_qual_report.transpose()

# %% [markdown]
# # Quality report

# %%
# To find high missing value and low cardinality
df_qual_report
# Out:
#                        Count % of Missing    Card.      Min.         Q1  \
# building_id         20216100          0.0     1449         0      393.0
# site_id             20216100          0.0       16         0        3.0
# square_feet         20216100          0.0     1397       283    32527.0
# year_built          20216100    59.990033      117    1900.0     1951.0
# floor_count         20216100    82.652772       19       1.0        1.0
# air_temperature     20216100     0.478124      620 -28.90625   8.601562
# cloud_coverage      20216100    43.655131       11       0.0        0.0
# dew_temperature     20216100     0.495348      523     -35.0        0.0
# precip_depth_1_hr   20216100    18.544739      129      -1.0        0.0
# sea_level_pressure  20216100     6.092515      134     968.0     1011.5
# wind_direction      20216100     7.167792       44       0.0       70.0
# wind_speed          20216100     0.710701       59       0.0   2.099609
# ...

# %% [markdown]
# # Missing value viasualization

# %%
df.columns
# Out:
# Index(['timestamp', 'building_id', 'site_id', 'square_feet', 'year_built',
#        'floor_count', 'air_temperature', 'cloud_coverage', 'dew_temperature',
#        'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction',
#        'wind_speed', 'meter', 'meter_reading', 'day', 'month'],
#       dtype='object')

# %%
condition_miss = df['site_id'] == 1
check = df.loc[condition_miss,['square_feet', 'year_built',
       'floor_count', 'air_temperature', 'cloud_coverage', 'dew_temperature',
       'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction',
       'wind_speed']]

missingno.matrix(check)
# Out:
# <AxesSubplot:>

# %%
for i in range(0,1449):
    condition_miss = df['building_id'] == i
    check = df.loc[condition_miss,['square_feet', 'year_built',
       'floor_count', 'air_temperature', 'cloud_coverage', 'dew_temperature',
       'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction',
       'wind_speed']]
    missingno.matrix(check)

# %% [markdown]
# # Histogram for each feature

# %%
sns.histplot(df['square_feet'], bins=50)

# %%
sns.histplot(df['year_built'], bins=50)

# %%
sns.histplot(df['floor_count'])

# %%
sns.histplot(df['air_temperature'], bins=50)

# %%
sns.histplot(df['cloud_coverage'])

# %%
sns.histplot(df['dew_temperature'], bins=50)

# %%
sns.histplot(df['precip_depth_1_hr'])

# %%
sns.histplot(df['sea_level_pressure'], bins=50)

# %%
sns.histplot(df['wind_direction'], bins=50)

# %%
sns.histplot(df['wind_speed'], bins=50)

# %%
sns.histplot(df['meter'], bins=50)

# %%
sns.histplot(df['meter_reading'], bins=50)

# %%
condition0 = df['site_id']==0
df_site0 = df.loc[condition0]

condition1 = df['site_id']==1
df_site1 = df.loc[condition1]

# %%
df_site0.head()
# Out:
#    timestamp  building_id  site_id  square_feet  year_built  floor_count  \
# 0 2016-01-01            0        0         7432      2008.0          NaN
# 1 2016-01-01            1        0         2720      2004.0          NaN
# 2 2016-01-01            2        0         5376      1991.0          NaN
# 3 2016-01-01            3        0        23685      2002.0          NaN
# 4 2016-01-01            4        0       116607      1975.0          NaN
#
#    air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 0             25.0             6.0             20.0                NaN
# 1             25.0             6.0             20.0                NaN
# 2             25.0             6.0             20.0                NaN
# 3             25.0             6.0             20.0                NaN
# 4             25.0             6.0             20.0                NaN
#
#    sea_level_pressure  wind_direction  wind_speed meter  meter_reading  \
# ...

# %%
df_yearly_site0_bld = df_site0[['building_id','meter_reading']].groupby(['building_id']).sum()
df_yearly_site1_bld = df_site1[['building_id','meter_reading']].groupby(['building_id']).sum()
df_yearly_site1_bld.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 105 to 155
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   meter_reading  51 non-null     float32
# dtypes: float32(1)
# memory usage: 612.0 bytes

# %%
plt.rcParams['figure.figsize'] = [16, 5]

plt.title('Total energy consumption\n( 2016 - Site1 & Site2 )')
plt.xlabel('Building Num')
plt.ylabel('Energy(kW/h)')
plt.bar(df_yearly_site0_bld.index, df_yearly_site0_bld['meter_reading'], label='Site1')
plt.bar(df_yearly_site1_bld.index, df_yearly_site1_bld['meter_reading'], label='Site2')
plt.legend()
plt.show()

# %%
# building '0' lineplot per month
sns.lineplot(data = df_bld0, x='day', y= 'meter_reading', ci=None, estimator='mean')

# %%
num_col_list.remove('meter_reading')
feature = pd.pivot_table(data=df_bld0, index='month', values=num_col_list, aggfunc='mean')

for column in test.columns:
    plt.title(column)
    plt.xlabel('Month')
    plt.plot(feature[column])
    plt.show()

# %%
test = pd.pivot_table(data=df_bld0, index='month', values='meter_reading', aggfunc='mean')
plt.title('meter_reading')
plt.xlabel('Month')
plt.plot(test['meter_reading'])
plt.show()

# %%
df.tail()

# %%
df[['timestamp','building_id','meter','meter_reading','month']]

# %%
condition = df['meter']==0
df_met0 = df.loc[condition]
df_met0

# %%
index_0 = df_met0[df_met0['site_id']==0]['building_id'].values
index_0

# %%
new = df_met0.groupby(['site_id','building_id']).mean()
new.loc[0,:]

# %%
plt.title('Meter_reading')
plt.xlabel('Month')
plt.bar(index_0, new.loc[0,:].values)
plt.legend()
plt.show()

# for i in range(0,105):
#     plt.plot(new.loc[0,i,:].values)
